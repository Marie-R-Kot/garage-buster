# %%
import pandas as pd
import os
import sys
import yaml
#from dataset_manager import MapManager
import ultralytics
from ultralytics import YOLO
from IPython.display import display, Image
import matplotlib.pyplot as plt
from PIL import Image
import io

# %%
# Добавить папку x в путь Python
sys.path.append('../')  # если папка x на одном уровне с y
from dataset_manager import MapManager

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.228  Python-3.11.6 torch-2.9.1+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# Setup complete  (8 CPUs, 6.9 GB RAM, 99.6/237.9 GB disk)

# %%
def get_data_ready(download_maps =True):
    maps = MapManager('config.yaml')
    maps.get_url_file()
    maps.data_split()
    if download_maps:
        maps.download_maps()
    maps.label_split()
    maps.create_dataset_yaml()

# %%
model = YOLO('yolov8n.pt') 
device = 'cpu'

# %%
results = model.train(
    data='dataset.yaml',
    epochs=2,     
    imgsz=1280,
    device='cpu',
    batch=32 if device == 'cuda' else 8,
    workers=8 if device == 'cuda' else 2,
    
    degrees=180.0,       
    fliplr=0.5,           
    flipud=0.5,             
    #mosaic=1.0,            
    
    #translate=0.1,          
    # scale=0.2,              
    # lr0=0.01,
    # weight_decay=0.0005,
    patience=10,
    save=True,
    plots=True,
    cache=False,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228  Python-3.11.6 torch-2.9.1+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# ...
